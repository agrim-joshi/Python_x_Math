# %% [markdown]
# # How to check the virtual environment

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\agrim\anaconda3\envs\mlenv\python.exe

# %%
4+1+5
# Out:
# 10

# %%
3/4
# Out:
# 0.75

# %%
4/2
# Out:
# 2.0

# %%
23*3
# Out:
# 69

# %% [markdown]
# ## Order of operation matters
#
# ### _BODMAS_

# %%
1 + 3/4  #BODMAS
# Out:
# 1.75
