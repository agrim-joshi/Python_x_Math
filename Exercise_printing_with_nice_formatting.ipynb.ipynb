# %% [markdown]
# ## Practice Exercises
#
# ### Exercise 1: Basic Equation Display
#
# Create variables:
#
# ```Python
# x = 8
# y = 5
# ```
#
# Use `display()` and an f-string to show:
#
# ```
# 8 + 5 = 13
# ```
#
# ---
#
# ### Exercise 2: Pretty Math Output
#
# Using `Math()`, display:
#
# ```
# 8 + 5 = 13
# ```
#
# as a nicely formatted mathematical expression.
#
# ---
#
# ### Exercise 3: Fractions
#
# Use LaTeX to display the fraction:
#
# $
# \frac{7}{12}
# $
#
#
# ---
#
# ### Exercise 4: Multiplication with Formatting
#
# Let:
#
# ```python
# x = 5.2
# y = 3.7
# ```
#
# Display:
#
# ```
# 5.2 × 3.7 = 19.24
# ```
#
# rounded to **two decimal places**.
#
# ---
#
# ### Exercise 5: Exponents
#
# Create variables:
#
# ```Python
# base = 2
# power = 10
# ```
#
# Display:
#
# $
# 2^{10}=1024
# $
#
# using `Math()`.
#
# ---
#
# ### Exercise 6: Inequalities
#
# Display the following inequality using LaTeX:
#
# $
# x \geq y
# $
#
# Then display:
#
# $
# a \neq b
# $
#
# ---
#
# ### Exercise 7: Absolute Values
#
# Create:
#
# ```Python
# x = -8.7
# ```
#
# Display:
#
# $
# |-8.7| = 8.7
# $
#
# using both:
#
# 1. f-strings
# 2. `%g` formatting
#
# ---
#
# ### Exercise 8: Text Inside Equations
#
# Display:
#
# $
# 5^3 \text{ is } 125
# $
#
# using `\text{}`.
#
# ---
#
# ### Exercise 9: Powers Table
#
# Using a loop, display:
#
# $
# 2^1 = 2
# $
#
# $
# 2^2 = 4
# $
#
# $
# 2^3 = 8
# $
#
# up to
#
# $
# 2^{10} = 1024
# $
#
# ---
#
# ### Exercise 10: Even/Odd Challenge
#
# Write a loop from `-10` to `10`.
#
# Print whether each number is even or odd using aligned formatting.
#
# Expected style:
#
# ```
# -10 is an even number
#  -9 is an odd  number
#  -8 is an even number
# ```
#
# ---
#
# ## Challenge Exercise
#
# Create a multiplication table for 7 using LaTeX.
#
# Expected output:
#
# $
# 7 \times 1 = 7
# $
#
# $
# 7 \times 2 = 14
# $
#
# ...
#
# $
# 7 \times 10 = 70
# $
#
#
#
# ---
